# %% [markdown]
# # LSTM Sign Language Detection by Sairishabh Anand
#
# ![Oregon State University]
#
# ## BS Undergraduate

# %% [markdown]
# **LSTM MODEL**
# 1. Install and import dependencies
# 2. Keypoints using MP Holistic
# 3. Extract Keypoints
# 4. Setup Folders for Collection
# 5. Collect Keypoints Values for Training and Testing
# 6. Preprocess Data and Create Labels and Features
# 7. Build and Train LSTM Neural Network
# 8. Make Predictions
# 9. Save Weights
# 10. Evaluation using Confusion Matrix and Accuracy
# 11. Test in Real Time

# %% [markdown]
# # Install and Import Dependencies

# %%
# !pip install tensorflow opencv-python mediapipe scikit-learn matplotlib tensorflowjs
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -umpy (/nfs/stak/users/meenkass/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/nfs/stak/users/meenkass/.local/lib/python3.9/site-packages)
# Requirement already satisfied: tensorflow in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (2.18.0)
# Requirement already satisfied: opencv-python in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (4.11.0.86)
# Requirement already satisfied: mediapipe in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (0.10.20)
# Requirement already satisfied: scikit-learn in /usr/local/lib64/python3.9/site-packages (1.5.2)
# Requirement already satisfied: matplotlib in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: tensorflowjs in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (4.22.0)
# Requirement already satisfied: libclang>=13.0.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: packaging in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: wrapt>=1.11.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: six>=1.12.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: keras>=3.5.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.11.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: setuptools in /usr/lib/python3.9/site-packages (from tensorflow) (53.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: flatbuffers>=24.3.25 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (25.1.24)
# Requirement already satisfied: typing-extensions>=3.6.6 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: absl-py>=1.0.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: jaxlib in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from mediapipe) (0.4.30)
# Requirement already satisfied: attrs>=19.1.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from mediapipe) (25.1.0)
# Requirement already satisfied: sentencepiece in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: jax in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from mediapipe) (0.4.30)
# Requirement already satisfied: sounddevice>=0.4.4 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: opencv-contrib-python in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib64/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: cycler>=0.10 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from matplotlib) (4.55.6)
# Requirement already satisfied: pillow>=8 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: tf-keras>=2.13.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflowjs) (0.16.1)
# Requirement already satisfied: tensorflow-decision-forests>=1.5.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflowjs) (1.11.0)
# Requirement already satisfied: flax>=0.7.2 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflowjs) (0.8.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: orbax-checkpoint in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from flax>=0.7.2->tensorflowjs) (0.6.4)
# Requirement already satisfied: msgpack in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from flax>=0.7.2->tensorflowjs) (1.1.0)
# Requirement already satisfied: tensorstore in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from flax>=0.7.2->tensorflowjs) (0.1.69)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/lib64/python3.9/site-packages (from flax>=0.7.2->tensorflowjs) (5.4.1)
# Requirement already satisfied: rich>=11.1 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from flax>=0.7.2->tensorflowjs) (13.9.4)
# Requirement already satisfied: optax in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from flax>=0.7.2->tensorflowjs) (0.2.4)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.18.1)
# Requirement already satisfied: importlib-metadata>=4.6 in /usr/local/lib/python3.9/site-packages (from jax->mediapipe) (7.0.2)
# Requirement already satisfied: optree in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: namex in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow) (2.10)
# Requirement already satisfied: CFFI>=1.0 in /usr/lib64/python3.9/site-packages (from sounddevice>=0.4.4->mediapipe) (1.14.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: markdown>=2.6.8 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: wurlitzer in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: ydf in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.9.0)
# Requirement already satisfied: pandas in /usr/local/lib64/python3.9/site-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.2.3)
# Requirement already satisfied: pycparser in /usr/lib/python3.9/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.20)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: chex>=0.1.87 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.88)
# Requirement already satisfied: etils[epy] in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from optax->flax>=0.7.2->tensorflowjs) (1.5.2)
# Requirement already satisfied: humanize in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.11.0)
# Requirement already satisfied: nest_asyncio in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.9/site-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2024.2)
# Requirement already satisfied: toolz>=0.9.0 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from chex>=0.1.87->optax->flax>=0.7.2->tensorflowjs) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: fsspec in /nfs/stak/users/meenkass/.local/lib/python3.9/site-packages (from etils[epy]->optax->flax>=0.7.2->tensorflowjs) (2024.12.0)
# Requirement already satisfied: ply==3.11 in /usr/lib/python3.9/site-packages (from pycparser->CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (3.11)
# WARNING: Ignoring invalid distribution -umpy (/nfs/stak/users/meenkass/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/nfs/stak/users/meenkass/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/nfs/stak/users/meenkass/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/nfs/stak/users/meenkass/.local/lib/python3.9/site-packages)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
# Out:
# 2025-01-25 12:27:50.507064: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-25 12:27:50.511483: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-25 12:27:50.523429: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737836870.543942 1316293 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737836870.549672 1316293 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-25 12:27:50.571899: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR-CONVERSION BGR-to-RGB
    image.flags.writeable = False                  # Convert image to not-writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Convert image to writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR-COVERSION RGB-to-BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# [ WARN:0@6.139] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@6.140] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1737836875.738075 1316426 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1737836875.771197 1316426 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1737836875.777260 1316426 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1737836875.777421 1316425 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1737836875.779393 1316427 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1737836875.789169 1316426 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1737836875.789442 1316427 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1737836875.795822 1316425 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
draw_landmarks(frame, results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 draw_landmarks(frame, results)
#
# NameError: name 'frame' is not defined

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Extract Keypoint Values

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# # Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['cat', 'food', 'help'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30

# %%
signs = ['cat','food','help']

parent_folder = 'MP_Data'

if not os.path.exists(parent_folder):
    os.mkdir(parent_folder)
    for sign in signs:
        sign_folder = os.path.join(parent_folder, sign)
        os.mkdir(sign_folder)
        for i in range(30):
            subfolder = os.path.join(sign_folder, str(i))
            os.mkdir(subfolder)

# %% [markdown]
# # Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X = np.array(sequences)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %% [markdown]
# # Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)
#While training access tensorboard
#tensorboard --logdir=.

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# 3/3 [==============================] - 0s 95ms/step - loss: 5.3714e-07 - categorical_accuracy: 1.0000
# Epoch 638/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 5.3714e-07 - categorical_accuracy: 1.0000
# Epoch 639/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 5.3714e-07 - categorical_accuracy: 1.0000
# Epoch 640/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 5.3434e-07 - categorical_accuracy: 1.0000
# Epoch 641/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 5.3294e-07 - categorical_accuracy: 1.0000
# Epoch 642/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 5.3294e-07 - categorical_accuracy: 1.0000
# Epoch 643/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 5.3294e-07 - categorical_accuracy: 1.0000
# Epoch 644/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 5.3153e-07 - categorical_accuracy: 1.0000
# Epoch 645/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 5.2873e-07 - categorical_accuracy: 1.0000
# Epoch 646/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 5.2733e-07 - categorical_accuracy: 1.0000
# Epoch 647/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 5.2733e-07 - categorical_accuracy: 1.0000
# Epoch 648/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 5.2172e-07 - categorical_accuracy: 1.0000
# Epoch 649/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 5.2031e-07 - categorical_accuracy: 1.0000
# Epoch 650/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 5.2031e-07 - categorical_accuracy: 1.0000
# Epoch 651/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 5.2031e-07 - categorical_accuracy: 1.0000
# Epoch 652/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 5.1751e-07 - categorical_accuracy: 1.0000
# Epoch 653/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 5.1330e-07 - categorical_accuracy: 1.0000
# Epoch 654/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 5.0909e-07 - categorical_accuracy: 1.0000
# Epoch 655/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 5.0769e-07 - categorical_accuracy: 1.0000
# Epoch 656/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 5.0348e-07 - categorical_accuracy: 1.0000
# Epoch 657/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 5.0348e-07 - categorical_accuracy: 1.0000
# Epoch 658/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 5.0208e-07 - categorical_accuracy: 1.0000
# Epoch 659/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 5.0068e-07 - categorical_accuracy: 1.0000
# Epoch 660/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 5.0068e-07 - categorical_accuracy: 1.0000
# Epoch 661/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 4.9928e-07 - categorical_accuracy: 1.0000
# Epoch 662/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 4.9647e-07 - categorical_accuracy: 1.0000
# Epoch 663/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 4.9507e-07 - categorical_accuracy: 1.0000
# Epoch 664/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 4.9226e-07 - categorical_accuracy: 1.0000
# Epoch 665/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 4.8946e-07 - categorical_accuracy: 1.0000
# Epoch 666/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 4.8806e-07 - categorical_accuracy: 1.0000
# Epoch 667/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 4.8385e-07 - categorical_accuracy: 1.0000
# Epoch 668/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 4.8245e-07 - categorical_accuracy: 1.0000
# Epoch 669/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 4.8104e-07 - categorical_accuracy: 1.0000
# Epoch 670/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 4.7684e-07 - categorical_accuracy: 1.0000
# Epoch 671/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 4.7684e-07 - categorical_accuracy: 1.0000
# Epoch 672/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 4.7684e-07 - categorical_accuracy: 1.0000
# Epoch 673/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 4.7403e-07 - categorical_accuracy: 1.0000
# Epoch 674/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 4.6982e-07 - categorical_accuracy: 1.0000
# Epoch 675/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 4.6842e-07 - categorical_accuracy: 1.0000
# Epoch 676/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 4.6562e-07 - categorical_accuracy: 1.0000
# Epoch 677/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 4.6421e-07 - categorical_accuracy: 1.0000
# Epoch 678/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 4.6141e-07 - categorical_accuracy: 1.0000
# Epoch 679/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 4.6001e-07 - categorical_accuracy: 1.0000
# Epoch 680/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 4.6001e-07 - categorical_accuracy: 1.0000
# Epoch 681/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 4.5860e-07 - categorical_accuracy: 1.0000
# Epoch 682/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 4.5580e-07 - categorical_accuracy: 1.0000
# Epoch 683/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 4.5580e-07 - categorical_accuracy: 1.0000
# Epoch 684/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 4.5440e-07 - categorical_accuracy: 1.0000
# Epoch 685/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 4.5440e-07 - categorical_accuracy: 1.0000
# Epoch 686/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 4.5299e-07 - categorical_accuracy: 1.0000
# Epoch 687/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 4.5019e-07 - categorical_accuracy: 1.0000
# Epoch 688/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 4.5019e-07 - categorical_accuracy: 1.0000
# Epoch 689/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.4879e-07 - categorical_accuracy: 1.0000
# Epoch 690/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 4.4739e-07 - categorical_accuracy: 1.0000
# Epoch 691/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 4.4458e-07 - categorical_accuracy: 1.0000
# Epoch 692/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 4.4318e-07 - categorical_accuracy: 1.0000
# Epoch 693/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 4.4318e-07 - categorical_accuracy: 1.0000
# Epoch 694/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 4.4178e-07 - categorical_accuracy: 1.0000
# Epoch 695/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 4.4037e-07 - categorical_accuracy: 1.0000
# Epoch 696/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 4.3757e-07 - categorical_accuracy: 1.0000
# Epoch 697/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 4.3617e-07 - categorical_accuracy: 1.0000
# Epoch 698/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 4.3617e-07 - categorical_accuracy: 1.0000
# Epoch 699/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 4.3617e-07 - categorical_accuracy: 1.0000
# Epoch 700/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 4.3476e-07 - categorical_accuracy: 1.0000
# Epoch 701/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 4.3196e-07 - categorical_accuracy: 1.0000
# Epoch 702/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 4.2915e-07 - categorical_accuracy: 1.0000
# Epoch 703/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 4.2775e-07 - categorical_accuracy: 1.0000
# Epoch 704/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 4.2775e-07 - categorical_accuracy: 1.0000
# Epoch 705/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 4.2775e-07 - categorical_accuracy: 1.0000
# Epoch 706/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 4.2635e-07 - categorical_accuracy: 1.0000
# Epoch 707/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 4.2354e-07 - categorical_accuracy: 1.0000
# Epoch 708/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 4.2074e-07 - categorical_accuracy: 1.0000
# Epoch 709/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 4.2074e-07 - categorical_accuracy: 1.0000
# Epoch 710/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 4.1934e-07 - categorical_accuracy: 1.0000
# Epoch 711/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 4.1793e-07 - categorical_accuracy: 1.0000
# Epoch 712/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 4.1513e-07 - categorical_accuracy: 1.0000
# Epoch 713/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 4.1513e-07 - categorical_accuracy: 1.0000
# Epoch 714/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 4.1513e-07 - categorical_accuracy: 1.0000
# Epoch 715/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 4.1373e-07 - categorical_accuracy: 1.0000
# Epoch 716/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 4.1373e-07 - categorical_accuracy: 1.0000
# Epoch 717/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 4.0531e-07 - categorical_accuracy: 1.0000
# Epoch 718/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 4.0531e-07 - categorical_accuracy: 1.0000
# Epoch 719/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 4.0531e-07 - categorical_accuracy: 1.0000
# Epoch 720/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 4.0391e-07 - categorical_accuracy: 1.0000
# Epoch 721/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 3.9970e-07 - categorical_accuracy: 1.0000
# Epoch 722/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 3.9549e-07 - categorical_accuracy: 1.0000
# Epoch 723/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 3.9549e-07 - categorical_accuracy: 1.0000
# Epoch 724/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 3.9269e-07 - categorical_accuracy: 1.0000
# Epoch 725/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 3.9269e-07 - categorical_accuracy: 1.0000
# Epoch 726/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 3.9129e-07 - categorical_accuracy: 1.0000
# Epoch 727/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 3.8988e-07 - categorical_accuracy: 1.0000
# Epoch 728/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 3.8988e-07 - categorical_accuracy: 1.0000
# Epoch 729/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 3.8848e-07 - categorical_accuracy: 1.0000
# Epoch 730/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 3.8708e-07 - categorical_accuracy: 1.0000
# Epoch 731/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 3.8568e-07 - categorical_accuracy: 1.0000
# Epoch 732/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 3.8568e-07 - categorical_accuracy: 1.0000
# Epoch 733/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 3.8287e-07 - categorical_accuracy: 1.0000
# Epoch 734/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 3.8287e-07 - categorical_accuracy: 1.0000
# Epoch 735/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 3.8147e-07 - categorical_accuracy: 1.0000
# Epoch 736/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 3.7866e-07 - categorical_accuracy: 1.0000
# Epoch 737/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 3.7726e-07 - categorical_accuracy: 1.0000
# Epoch 738/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 3.7446e-07 - categorical_accuracy: 1.0000
# Epoch 739/2000
# 3/3 [==============================] - 0s 137ms/step - loss: 3.7446e-07 - categorical_accuracy: 1.0000
# Epoch 740/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 3.7446e-07 - categorical_accuracy: 1.0000
# Epoch 741/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 3.7165e-07 - categorical_accuracy: 1.0000
# Epoch 742/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 3.7165e-07 - categorical_accuracy: 1.0000
# Epoch 743/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 3.7025e-07 - categorical_accuracy: 1.0000
# Epoch 744/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 3.6885e-07 - categorical_accuracy: 1.0000
# Epoch 745/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 3.6604e-07 - categorical_accuracy: 1.0000
# Epoch 746/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 3.6464e-07 - categorical_accuracy: 1.0000
# Epoch 747/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.6324e-07 - categorical_accuracy: 1.0000
# Epoch 748/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 3.6183e-07 - categorical_accuracy: 1.0000
# Epoch 749/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 3.6043e-07 - categorical_accuracy: 1.0000
# Epoch 750/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 3.6043e-07 - categorical_accuracy: 1.0000
# Epoch 751/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 3.6043e-07 - categorical_accuracy: 1.0000
# Epoch 752/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 3.5903e-07 - categorical_accuracy: 1.0000
# Epoch 753/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 3.5623e-07 - categorical_accuracy: 1.0000
# Epoch 754/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 3.5623e-07 - categorical_accuracy: 1.0000
# Epoch 755/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 3.5623e-07 - categorical_accuracy: 1.0000
# Epoch 756/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 3.5623e-07 - categorical_accuracy: 1.0000
# Epoch 757/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 3.5482e-07 - categorical_accuracy: 1.0000
# Epoch 758/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 3.5482e-07 - categorical_accuracy: 1.0000
# Epoch 759/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 3.5482e-07 - categorical_accuracy: 1.0000
# Epoch 760/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 3.5342e-07 - categorical_accuracy: 1.0000
# Epoch 761/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 3.5062e-07 - categorical_accuracy: 1.0000
# Epoch 762/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 3.5062e-07 - categorical_accuracy: 1.0000
# Epoch 763/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 3.4921e-07 - categorical_accuracy: 1.0000
# Epoch 764/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 3.4641e-07 - categorical_accuracy: 1.0000
# Epoch 765/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 3.4641e-07 - categorical_accuracy: 1.0000
# Epoch 766/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 3.4220e-07 - categorical_accuracy: 1.0000
# Epoch 767/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 3.4080e-07 - categorical_accuracy: 1.0000
# Epoch 768/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 3.3940e-07 - categorical_accuracy: 1.0000
# Epoch 769/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 3.3799e-07 - categorical_accuracy: 1.0000
# Epoch 770/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 3.3519e-07 - categorical_accuracy: 1.0000
# Epoch 771/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 3.3519e-07 - categorical_accuracy: 1.0000
# Epoch 772/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 3.3519e-07 - categorical_accuracy: 1.0000
# Epoch 773/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 3.3379e-07 - categorical_accuracy: 1.0000
# Epoch 774/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 3.2958e-07 - categorical_accuracy: 1.0000
# Epoch 775/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.2958e-07 - categorical_accuracy: 1.0000
# Epoch 776/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 3.2958e-07 - categorical_accuracy: 1.0000
# Epoch 777/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 3.2818e-07 - categorical_accuracy: 1.0000
# Epoch 778/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 3.2818e-07 - categorical_accuracy: 1.0000
# Epoch 779/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 3.2677e-07 - categorical_accuracy: 1.0000
# Epoch 780/2000
# 3/3 [==============================] - 0s 78ms/step - loss: 3.2537e-07 - categorical_accuracy: 1.0000
# Epoch 781/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 3.2257e-07 - categorical_accuracy: 1.0000
# Epoch 782/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 3.2257e-07 - categorical_accuracy: 1.0000
# Epoch 783/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 3.2257e-07 - categorical_accuracy: 1.0000
# Epoch 784/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 3.1976e-07 - categorical_accuracy: 1.0000
# Epoch 785/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 3.1836e-07 - categorical_accuracy: 1.0000
# Epoch 786/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 3.1696e-07 - categorical_accuracy: 1.0000
# Epoch 787/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 3.1696e-07 - categorical_accuracy: 1.0000
# Epoch 788/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 3.1696e-07 - categorical_accuracy: 1.0000
# Epoch 789/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 3.1696e-07 - categorical_accuracy: 1.0000
# Epoch 790/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 3.1555e-07 - categorical_accuracy: 1.0000
# Epoch 791/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 3.1555e-07 - categorical_accuracy: 1.0000
# Epoch 792/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 3.1555e-07 - categorical_accuracy: 1.0000
# Epoch 793/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 3.1555e-07 - categorical_accuracy: 1.0000
# Epoch 794/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 3.1135e-07 - categorical_accuracy: 1.0000
# Epoch 795/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 3.0854e-07 - categorical_accuracy: 1.0000
# Epoch 796/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 3.0574e-07 - categorical_accuracy: 1.0000
# Epoch 797/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 3.0574e-07 - categorical_accuracy: 1.0000
# Epoch 798/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 3.0293e-07 - categorical_accuracy: 1.0000
# Epoch 799/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 3.0153e-07 - categorical_accuracy: 1.0000
# Epoch 800/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 3.0013e-07 - categorical_accuracy: 1.0000
# Epoch 801/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 3.0013e-07 - categorical_accuracy: 1.0000
# Epoch 802/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 2.9732e-07 - categorical_accuracy: 1.0000
# Epoch 803/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.9732e-07 - categorical_accuracy: 1.0000
# Epoch 804/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.9732e-07 - categorical_accuracy: 1.0000
# Epoch 805/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.9592e-07 - categorical_accuracy: 1.0000
# Epoch 806/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 2.9311e-07 - categorical_accuracy: 1.0000
# Epoch 807/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 2.9031e-07 - categorical_accuracy: 1.0000
# Epoch 808/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 2.8891e-07 - categorical_accuracy: 1.0000
# Epoch 809/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.8891e-07 - categorical_accuracy: 1.0000
# Epoch 810/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 2.8891e-07 - categorical_accuracy: 1.0000
# Epoch 811/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 2.8891e-07 - categorical_accuracy: 1.0000
# Epoch 812/2000
# 3/3 [==============================] - 0s 137ms/step - loss: 2.8891e-07 - categorical_accuracy: 1.0000
# Epoch 813/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 2.8750e-07 - categorical_accuracy: 1.0000
# Epoch 814/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 2.8750e-07 - categorical_accuracy: 1.0000
# Epoch 815/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 2.8610e-07 - categorical_accuracy: 1.0000
# Epoch 816/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.8610e-07 - categorical_accuracy: 1.0000
# Epoch 817/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.8470e-07 - categorical_accuracy: 1.0000
# Epoch 818/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 2.8470e-07 - categorical_accuracy: 1.0000
# Epoch 819/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.8049e-07 - categorical_accuracy: 1.0000
# Epoch 820/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 2.8049e-07 - categorical_accuracy: 1.0000
# Epoch 821/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 2.7909e-07 - categorical_accuracy: 1.0000
# Epoch 822/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.7769e-07 - categorical_accuracy: 1.0000
# Epoch 823/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.7628e-07 - categorical_accuracy: 1.0000
# Epoch 824/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 2.7628e-07 - categorical_accuracy: 1.0000
# Epoch 825/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 2.7208e-07 - categorical_accuracy: 1.0000
# Epoch 826/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 2.7068e-07 - categorical_accuracy: 1.0000
# Epoch 827/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.7068e-07 - categorical_accuracy: 1.0000
# Epoch 828/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.6927e-07 - categorical_accuracy: 1.0000
# Epoch 829/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 2.6787e-07 - categorical_accuracy: 1.0000
# Epoch 830/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 2.6787e-07 - categorical_accuracy: 1.0000
# Epoch 831/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 2.6787e-07 - categorical_accuracy: 1.0000
# Epoch 832/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 2.6787e-07 - categorical_accuracy: 1.0000
# Epoch 833/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.6647e-07 - categorical_accuracy: 1.0000
# Epoch 834/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.6647e-07 - categorical_accuracy: 1.0000
# Epoch 835/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.6366e-07 - categorical_accuracy: 1.0000
# Epoch 836/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.6226e-07 - categorical_accuracy: 1.0000
# Epoch 837/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.6226e-07 - categorical_accuracy: 1.0000
# Epoch 838/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.6226e-07 - categorical_accuracy: 1.0000
# Epoch 839/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.6226e-07 - categorical_accuracy: 1.0000
# Epoch 840/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.6226e-07 - categorical_accuracy: 1.0000
# Epoch 841/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.5946e-07 - categorical_accuracy: 1.0000
# Epoch 842/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.5665e-07 - categorical_accuracy: 1.0000
# Epoch 843/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.5665e-07 - categorical_accuracy: 1.0000
# Epoch 844/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.5525e-07 - categorical_accuracy: 1.0000
# Epoch 845/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.5525e-07 - categorical_accuracy: 1.0000
# Epoch 846/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.5525e-07 - categorical_accuracy: 1.0000
# Epoch 847/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.5385e-07 - categorical_accuracy: 1.0000
# Epoch 848/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.5385e-07 - categorical_accuracy: 1.0000
# Epoch 849/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.5244e-07 - categorical_accuracy: 1.0000
# Epoch 850/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.5244e-07 - categorical_accuracy: 1.0000
# Epoch 851/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 2.5244e-07 - categorical_accuracy: 1.0000
# Epoch 852/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.5244e-07 - categorical_accuracy: 1.0000
# Epoch 853/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.5244e-07 - categorical_accuracy: 1.0000
# Epoch 854/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.5244e-07 - categorical_accuracy: 1.0000
# Epoch 855/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.5244e-07 - categorical_accuracy: 1.0000
# Epoch 856/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.5104e-07 - categorical_accuracy: 1.0000
# Epoch 857/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.4964e-07 - categorical_accuracy: 1.0000
# Epoch 858/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.4824e-07 - categorical_accuracy: 1.0000
# Epoch 859/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.4824e-07 - categorical_accuracy: 1.0000
# Epoch 860/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.4824e-07 - categorical_accuracy: 1.0000
# Epoch 861/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.4683e-07 - categorical_accuracy: 1.0000
# Epoch 862/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.4263e-07 - categorical_accuracy: 1.0000
# Epoch 863/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.4122e-07 - categorical_accuracy: 1.0000
# Epoch 864/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.3982e-07 - categorical_accuracy: 1.0000
# Epoch 865/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.3842e-07 - categorical_accuracy: 1.0000
# Epoch 866/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.3842e-07 - categorical_accuracy: 1.0000
# Epoch 867/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.3842e-07 - categorical_accuracy: 1.0000
# Epoch 868/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.3842e-07 - categorical_accuracy: 1.0000
# Epoch 869/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 2.3702e-07 - categorical_accuracy: 1.0000
# Epoch 870/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.3702e-07 - categorical_accuracy: 1.0000
# Epoch 871/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.3702e-07 - categorical_accuracy: 1.0000
# Epoch 872/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.3702e-07 - categorical_accuracy: 1.0000
# Epoch 873/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.3561e-07 - categorical_accuracy: 1.0000
# Epoch 874/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.3561e-07 - categorical_accuracy: 1.0000
# Epoch 875/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.3561e-07 - categorical_accuracy: 1.0000
# Epoch 876/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.3561e-07 - categorical_accuracy: 1.0000
# Epoch 877/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 2.3561e-07 - categorical_accuracy: 1.0000
# Epoch 878/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.3561e-07 - categorical_accuracy: 1.0000
# Epoch 879/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.3561e-07 - categorical_accuracy: 1.0000
# Epoch 880/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.3141e-07 - categorical_accuracy: 1.0000
# Epoch 881/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.3000e-07 - categorical_accuracy: 1.0000
# Epoch 882/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.2860e-07 - categorical_accuracy: 1.0000
# Epoch 883/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.2860e-07 - categorical_accuracy: 1.0000
# Epoch 884/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.2860e-07 - categorical_accuracy: 1.0000
# Epoch 885/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.2720e-07 - categorical_accuracy: 1.0000
# Epoch 886/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.2720e-07 - categorical_accuracy: 1.0000
# Epoch 887/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.2720e-07 - categorical_accuracy: 1.0000
# Epoch 888/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.2720e-07 - categorical_accuracy: 1.0000
# Epoch 889/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.2580e-07 - categorical_accuracy: 1.0000
# Epoch 890/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.2299e-07 - categorical_accuracy: 1.0000
# Epoch 891/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.2299e-07 - categorical_accuracy: 1.0000
# Epoch 892/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.2299e-07 - categorical_accuracy: 1.0000
# Epoch 893/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.2159e-07 - categorical_accuracy: 1.0000
# Epoch 894/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.2159e-07 - categorical_accuracy: 1.0000
# Epoch 895/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.2159e-07 - categorical_accuracy: 1.0000
# Epoch 896/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.2019e-07 - categorical_accuracy: 1.0000
# Epoch 897/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.1878e-07 - categorical_accuracy: 1.0000
# Epoch 898/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.1738e-07 - categorical_accuracy: 1.0000
# Epoch 899/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.1598e-07 - categorical_accuracy: 1.0000
# Epoch 900/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.1598e-07 - categorical_accuracy: 1.0000
# Epoch 901/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.1598e-07 - categorical_accuracy: 1.0000
# Epoch 902/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 2.1598e-07 - categorical_accuracy: 1.0000
# Epoch 903/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.1598e-07 - categorical_accuracy: 1.0000
# Epoch 904/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.1598e-07 - categorical_accuracy: 1.0000
# Epoch 905/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.1598e-07 - categorical_accuracy: 1.0000
# Epoch 906/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.1317e-07 - categorical_accuracy: 1.0000
# Epoch 907/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.1317e-07 - categorical_accuracy: 1.0000
# Epoch 908/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.1177e-07 - categorical_accuracy: 1.0000
# Epoch 909/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.1037e-07 - categorical_accuracy: 1.0000
# Epoch 910/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.1037e-07 - categorical_accuracy: 1.0000
# Epoch 911/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.1037e-07 - categorical_accuracy: 1.0000
# Epoch 912/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.1037e-07 - categorical_accuracy: 1.0000
# Epoch 913/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.1037e-07 - categorical_accuracy: 1.0000
# Epoch 914/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.1037e-07 - categorical_accuracy: 1.0000
# Epoch 915/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.1037e-07 - categorical_accuracy: 1.0000
# Epoch 916/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.0897e-07 - categorical_accuracy: 1.0000
# Epoch 917/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 2.0897e-07 - categorical_accuracy: 1.0000
# Epoch 918/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.0756e-07 - categorical_accuracy: 1.0000
# Epoch 919/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.0756e-07 - categorical_accuracy: 1.0000
# Epoch 920/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.0476e-07 - categorical_accuracy: 1.0000
# Epoch 921/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.0476e-07 - categorical_accuracy: 1.0000
# Epoch 922/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.0336e-07 - categorical_accuracy: 1.0000
# Epoch 923/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.0336e-07 - categorical_accuracy: 1.0000
# Epoch 924/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.0195e-07 - categorical_accuracy: 1.0000
# Epoch 925/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 2.0195e-07 - categorical_accuracy: 1.0000
# Epoch 926/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.0195e-07 - categorical_accuracy: 1.0000
# Epoch 927/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.0055e-07 - categorical_accuracy: 1.0000
# Epoch 928/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.0055e-07 - categorical_accuracy: 1.0000
# Epoch 929/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.9775e-07 - categorical_accuracy: 1.0000
# Epoch 930/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.9634e-07 - categorical_accuracy: 1.0000
# Epoch 931/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.9634e-07 - categorical_accuracy: 1.0000
# Epoch 932/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.9634e-07 - categorical_accuracy: 1.0000
# Epoch 933/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.9354e-07 - categorical_accuracy: 1.0000
# Epoch 934/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.9214e-07 - categorical_accuracy: 1.0000
# Epoch 935/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.9073e-07 - categorical_accuracy: 1.0000
# Epoch 936/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.9073e-07 - categorical_accuracy: 1.0000
# Epoch 937/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.8933e-07 - categorical_accuracy: 1.0000
# Epoch 938/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 1.8793e-07 - categorical_accuracy: 1.0000
# Epoch 939/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.8793e-07 - categorical_accuracy: 1.0000
# Epoch 940/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.8653e-07 - categorical_accuracy: 1.0000
# Epoch 941/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.8372e-07 - categorical_accuracy: 1.0000
# Epoch 942/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.8372e-07 - categorical_accuracy: 1.0000
# Epoch 943/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 1.8092e-07 - categorical_accuracy: 1.0000
# Epoch 944/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.7671e-07 - categorical_accuracy: 1.0000
# Epoch 945/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.7531e-07 - categorical_accuracy: 1.0000
# Epoch 946/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.7250e-07 - categorical_accuracy: 1.0000
# Epoch 947/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.7110e-07 - categorical_accuracy: 1.0000
# Epoch 948/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.6970e-07 - categorical_accuracy: 1.0000
# Epoch 949/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.6549e-07 - categorical_accuracy: 1.0000
# Epoch 950/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.6409e-07 - categorical_accuracy: 1.0000
# Epoch 951/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 1.6409e-07 - categorical_accuracy: 1.0000
# Epoch 952/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.6269e-07 - categorical_accuracy: 1.0000
# Epoch 953/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.6269e-07 - categorical_accuracy: 1.0000
# Epoch 954/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.5708e-07 - categorical_accuracy: 1.0000
# Epoch 955/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.4586e-07 - categorical_accuracy: 1.0000
# Epoch 956/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.3884e-07 - categorical_accuracy: 1.0000
# Epoch 957/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.3323e-07 - categorical_accuracy: 1.0000
# Epoch 958/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.2762e-07 - categorical_accuracy: 1.0000
# Epoch 959/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.2061e-07 - categorical_accuracy: 1.0000
# Epoch 960/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.1781e-07 - categorical_accuracy: 1.0000
# Epoch 961/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.0659e-07 - categorical_accuracy: 1.0000
# Epoch 962/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.0238e-07 - categorical_accuracy: 1.0000
# Epoch 963/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 9.8172e-08 - categorical_accuracy: 1.0000
# Epoch 964/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 9.1160e-08 - categorical_accuracy: 1.0000
# Epoch 965/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 8.5550e-08 - categorical_accuracy: 1.0000
# Epoch 966/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 8.1343e-08 - categorical_accuracy: 1.0000
# Epoch 967/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 7.8538e-08 - categorical_accuracy: 1.0000
# Epoch 968/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 7.7135e-08 - categorical_accuracy: 1.0000
# Epoch 969/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 7.5733e-08 - categorical_accuracy: 1.0000
# Epoch 970/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 7.4330e-08 - categorical_accuracy: 1.0000
# Epoch 971/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 7.4330e-08 - categorical_accuracy: 1.0000
# Epoch 972/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 7.4330e-08 - categorical_accuracy: 1.0000
# Epoch 973/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 7.2928e-08 - categorical_accuracy: 1.0000
# Epoch 974/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 7.2928e-08 - categorical_accuracy: 1.0000
# Epoch 975/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 7.1526e-08 - categorical_accuracy: 1.0000
# Epoch 976/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 6.8721e-08 - categorical_accuracy: 1.0000
# Epoch 977/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 6.5916e-08 - categorical_accuracy: 1.0000
# Epoch 978/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 6.4513e-08 - categorical_accuracy: 1.0000
# Epoch 979/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 6.4513e-08 - categorical_accuracy: 1.0000
# Epoch 980/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 6.4513e-08 - categorical_accuracy: 1.0000
# Epoch 981/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 6.3111e-08 - categorical_accuracy: 1.0000
# Epoch 982/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 6.0306e-08 - categorical_accuracy: 1.0000
# Epoch 983/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 5.6098e-08 - categorical_accuracy: 1.0000
# Epoch 984/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 5.3294e-08 - categorical_accuracy: 1.0000
# Epoch 985/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 5.3294e-08 - categorical_accuracy: 1.0000
# Epoch 986/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 5.3294e-08 - categorical_accuracy: 1.0000
# Epoch 987/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 5.1891e-08 - categorical_accuracy: 1.0000
# Epoch 988/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 5.0489e-08 - categorical_accuracy: 1.0000
# Epoch 989/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 4.7684e-08 - categorical_accuracy: 1.0000
# Epoch 990/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 4.6281e-08 - categorical_accuracy: 1.0000
# Epoch 991/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 4.6281e-08 - categorical_accuracy: 1.0000
# Epoch 992/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 4.6281e-08 - categorical_accuracy: 1.0000
# Epoch 993/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 4.4879e-08 - categorical_accuracy: 1.0000
# Epoch 994/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 4.2074e-08 - categorical_accuracy: 1.0000
# Epoch 995/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 4.0671e-08 - categorical_accuracy: 1.0000
# Epoch 996/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 4.0671e-08 - categorical_accuracy: 1.0000
# Epoch 997/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 3.9269e-08 - categorical_accuracy: 1.0000
# Epoch 998/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 3.7866e-08 - categorical_accuracy: 1.0000
# Epoch 999/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 3.6464e-08 - categorical_accuracy: 1.0000
# Epoch 1000/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 3.5062e-08 - categorical_accuracy: 1.0000
# Epoch 1001/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 3.5062e-08 - categorical_accuracy: 1.0000
# Epoch 1002/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 3.5062e-08 - categorical_accuracy: 1.0000
# Epoch 1003/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 3.5062e-08 - categorical_accuracy: 1.0000
# Epoch 1004/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 3.5062e-08 - categorical_accuracy: 1.0000
# Epoch 1005/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 3.3659e-08 - categorical_accuracy: 1.0000
# Epoch 1006/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 3.2257e-08 - categorical_accuracy: 1.0000
# Epoch 1007/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 3.2257e-08 - categorical_accuracy: 1.0000
# Epoch 1008/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.9452e-08 - categorical_accuracy: 1.0000
# Epoch 1009/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.9452e-08 - categorical_accuracy: 1.0000
# Epoch 1010/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.8049e-08 - categorical_accuracy: 1.0000
# Epoch 1011/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.8049e-08 - categorical_accuracy: 1.0000
# Epoch 1012/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.6647e-08 - categorical_accuracy: 1.0000
# Epoch 1013/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.6647e-08 - categorical_accuracy: 1.0000
# Epoch 1014/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 2.6647e-08 - categorical_accuracy: 1.0000
# Epoch 1015/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.5244e-08 - categorical_accuracy: 1.0000
# Epoch 1016/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.5244e-08 - categorical_accuracy: 1.0000
# Epoch 1017/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.2439e-08 - categorical_accuracy: 1.0000
# Epoch 1018/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 2.2439e-08 - categorical_accuracy: 1.0000
# Epoch 1019/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 2.2439e-08 - categorical_accuracy: 1.0000
# Epoch 1020/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 2.2439e-08 - categorical_accuracy: 1.0000
# Epoch 1021/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 2.2439e-08 - categorical_accuracy: 1.0000
# Epoch 1022/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 2.2439e-08 - categorical_accuracy: 1.0000
# Epoch 1023/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 2.1037e-08 - categorical_accuracy: 1.0000
# Epoch 1024/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 1.9634e-08 - categorical_accuracy: 1.0000
# Epoch 1025/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.9634e-08 - categorical_accuracy: 1.0000
# Epoch 1026/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 1.8232e-08 - categorical_accuracy: 1.0000
# Epoch 1027/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.6830e-08 - categorical_accuracy: 1.0000
# Epoch 1028/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.6830e-08 - categorical_accuracy: 1.0000
# Epoch 1029/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.6830e-08 - categorical_accuracy: 1.0000
# Epoch 1030/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.6830e-08 - categorical_accuracy: 1.0000
# Epoch 1031/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.6830e-08 - categorical_accuracy: 1.0000
# Epoch 1032/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 1.5427e-08 - categorical_accuracy: 1.0000
# Epoch 1033/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.5427e-08 - categorical_accuracy: 1.0000
# Epoch 1034/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.5427e-08 - categorical_accuracy: 1.0000
# Epoch 1035/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.5427e-08 - categorical_accuracy: 1.0000
# Epoch 1036/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.5427e-08 - categorical_accuracy: 1.0000
# Epoch 1037/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.5427e-08 - categorical_accuracy: 1.0000
# Epoch 1038/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 1.4025e-08 - categorical_accuracy: 1.0000
# Epoch 1039/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.4025e-08 - categorical_accuracy: 1.0000
# Epoch 1040/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.2622e-08 - categorical_accuracy: 1.0000
# Epoch 1041/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 1.2622e-08 - categorical_accuracy: 1.0000
# Epoch 1042/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.2622e-08 - categorical_accuracy: 1.0000
# Epoch 1043/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.2622e-08 - categorical_accuracy: 1.0000
# Epoch 1044/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 1.2622e-08 - categorical_accuracy: 1.0000
# Epoch 1045/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 1.2622e-08 - categorical_accuracy: 1.0000
# Epoch 1046/2000
# ...
# Epoch 1866/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1867/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1868/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1869/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1870/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1871/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1872/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1873/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1874/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1875/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1876/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1877/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1878/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1879/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1880/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1881/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1882/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1883/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1884/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1885/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1886/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1887/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1888/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1889/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1890/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1891/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1892/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1893/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1894/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1895/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1896/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1897/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1898/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1899/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1900/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1901/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1902/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1903/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1904/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1905/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1906/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1907/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1908/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1909/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1910/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1911/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1912/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1913/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1914/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1915/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1916/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1917/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1918/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1919/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1920/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1921/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1922/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1923/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1924/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1925/2000
# 3/3 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1926/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1927/2000
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1928/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1929/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1930/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1931/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1932/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1933/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1934/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1935/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1936/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1937/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1938/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1939/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1940/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1941/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1942/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1943/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1944/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1945/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1946/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1947/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1948/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1949/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1950/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1951/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1952/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1953/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1954/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1955/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1956/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1957/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1958/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1959/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1960/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1961/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1962/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1963/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1964/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1965/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1966/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1967/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1968/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1969/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1970/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1971/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1972/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1973/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1974/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1975/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1976/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1977/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1978/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1979/2000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1980/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1981/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1982/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1983/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1984/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1985/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1986/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1987/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1988/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1989/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1990/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1991/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1992/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1993/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1994/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1995/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1996/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1997/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1998/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 1999/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000
# Epoch 2000/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0000e+00 - categorical_accuracy: 1.0000

# %%
model.summary()

# %%
import visualkeras
from PIL import ImageFont
font = ImageFont.truetype("arial.ttf", 12)
visualkeras.layered_view(model, legend=True, font=font,spacing=100)

# %% [markdown]
# # Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[4])]

# %%
actions[np.argmax(y_test[4])]

# %% [markdown]
# # Save Weights

# %%
model.save('./model.h5')
model.save_weights('./model_weights.h5');

# %%
del model

# %%
import tensorflow as tf
model = tf.keras.models.load_model('model.h5')

# %%
model.load_weights('model_weights.h5')

# %% [markdown]
# # Evaluation using Confusion Matrix

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)

# %%
accuracy_score(ytrue, yhat)

# %% [markdown]
# # Realtime Test

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
# !pip install numpy --upgrade

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import tensorflow as tf

signs = ['hello', 'thanks', 'iloveyou']
actions = np.array(['hello', 'thanks', 'iloveyou'])


mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR-CONVERSION BGR-to-RGB
    image.flags.writeable = False                  # Convert image to not-writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Convert image to writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR-COVERSION RGB-to-BGR
    return image, results

colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             ) 
    
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])
    
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

model = tf.keras.models.load_model('model.h5')
model.load_weights('model_weights.h5')
model.summary()

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        #print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            #print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            #image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        #print(sentence)
        #word = sentence[-1:]
        #convert_to_audio(word[0]) if (len(word) != 0) else print("word not detected yet")
        #convert_to_audio(word[0])
        
        # Show to screen
        cv2.imshow('Realtime LSTM Sign Language Detection', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
